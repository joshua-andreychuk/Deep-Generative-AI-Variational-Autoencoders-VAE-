# %%
# !python main.py --model vae --train --device gpu
# Out:
# Using device:  cuda
# Model name: model=vae_z=10_run=0000
# Saved to checkpoints\model=vae_z=10_run=0000\model-10000.pt
# Saved to checkpoints\model=vae_z=10_run=0000\model-20000.pt
# ********************************************************************************
# LOG-LIKELIHOOD LOWER BOUNDS ON TEST SUBSET
# ********************************************************************************
# NELBO: 101.51612091064453. KL: 19.47377586364746. Rec: 82.04234313964844
# ...
#   3%|3         | 628/20000 [00:09<04:53, 65.91it/s, loss=1.28e+02]
# ...
# ...
# 100%|##########| 20000/20000 [05:14<00:00, 63.54it/s, loss=9.78e+01]
